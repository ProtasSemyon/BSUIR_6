# %%
import pandas as pd
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
PATH = 'USA_cars.csv'
dataset = pd.read_csv(PATH)

# %%
for column in dataset:
    if type(dataset[column][0]) is str:
        dataset[column] = pd.factorize(dataset[column])[0]
        
sns.heatmap(
    round(
        abs(dataset.corr()),
        1,
    ),
    annot=True,
)
# Out:
# <Axes: >

# %%
train_input, test_input, train_output, test_output = train_test_split(
    dataset.drop('brand', axis=1),
    dataset["brand"],
    test_size=0.2
)

# %%
model = GaussianNB()
model.fit(train_input, train_output)
predictions = model.predict(test_input)
accuracy = metrics.accuracy_score(predictions, test_output)
print(f"Точность модели на тестовом участке = {accuracy}")
# Out:
# Точность модели на тестовом участке = 0.8473053892215568
